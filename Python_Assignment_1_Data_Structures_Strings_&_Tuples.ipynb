# %% [markdown]
# 1. String Concatenation:
#
# Write a Python program that takes two strings i.e string 1 “Hello ”, string 2 get name as
# input from the user and concatenates them together. Display the concatenated string as
# the output.

# %%
#String Concatenation
text1 = "Hello"
text2 = "Prithviraj"
concetenated_string = text1 + " " + text2
print(concetenated_string)
# Out:
# Hello Prithviraj

# %% [markdown]
# concatenate string 3 “, welcome to Python programming” to the existing string and
# display the output string.

# %%
text3 = ", Welcome to Python Programming"
final_string = concetenated_string + text3
print(final_string)
# Out:
# Hello Prithviraj, Welcome to Python Programming

# %% [markdown]
# 2. String Slicing and Indexing:

# %% [markdown]
# Write a Python program using the above concatenated string as input and performs the
# following tasks:

# %%
#Print the first character of the string.
first_character = final_string[0]
print(final_string[0])
# Out:
# H

# %%
#Print the last character of the string
last_chr = final_string[-1]
print(final_string[-1])
# Out:
# g

# %%
#Print the first 5 characters of the string
first5 = final_string[:5]
print(final_string[:5])
# Out:
# Hello

# %%
#Print the last 11 characters of the string
last11 = final_string[-11:]
print(final_string[-11:])
# Out:
# Programming

# %%
#Print the string in reverse.
reversed = final_string[::-1]
print(final_string[::-1])
# Out:
# gnimmargorP nohtyP ot emocleW ,jarivhtirP olleH

# %%
#Use slicing and print the word “Python” from the existing string
sliced_word = final_string[-18:-12]
print(final_string[-18:-12])
# Out:
# Python

# %% [markdown]
# 3. String Methods:
# Write a Python program that takes a string, strM = “Python beginner tutorial” and
# perform the following tasks:

# %%
#Convert the sentence to uppercase.
strM = "Python_beginner_tutorial"
print(strM.upper())
# Out:
# PYTHON_BEGINNER_TUTORIAL

# %%
#Convert the sentence to lowercase.
print(strM.lower())
# Out:
# python_beginner_tutorial

# %%
#Use Capitalize and return the sentence to the original input form
print(strM.capitalize())
# Out:
# Python_beginner_tutorial

# %%
#Count the total number of occurrences of character ‘t’ in the string
count_T= strM.count('t')
print(count_T)
# Out:
# 3

# %%
#Replace all occurrences of “Python” with “Machine Learning” in the input string

strM = "Python beginner tutorial"
replaced_string = strM.replace("Python", "Machine Learning")

print(replaced_string)
# Out:
# Machine Learning beginner tutorial

# %% [markdown]
# Tuples (Creation, Modification and Access) :
# Create 1st tuple with values -> (10, 20, 30), 2nd tuple with values -> (40, 50, 60):

# %%
#Concatenate the two tuples and store it in “t_combine”

# Create 1st and 2nd tuples
tuple1 = (10, 20, 30)
tuple2 = (40, 50, 60)

# a. Concatenate the two tuples and store it in "t_combine"
t_combine = tuple1 + tuple2

print("Combined Tuple (t_combine):", t_combine)
# Out:
# Combined Tuple (t_combine): (10, 20, 30, 40, 50, 60)

# %%
#b. Repeat the elements of “t_combine” 3 times
repeated_tuple = t_combine * 3
print(repeated_tuple)
# Out:
# (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)

# %%
#Access the 3rd element from “t_combine”
third_element = t_combine[2]
print(third_element)
# Out:
# 30

# %%
#Access the first three elements from “t_combine”
first_three_elements = t_combine[:3]
print(first_three_elements)
# Out:
# (10, 20, 30)

# %%
#Access the last three elements from “t_combine”
last_three_elements = t_combine[-3:]
print(last_three_elements)
# Out:
# (40, 50, 60)
